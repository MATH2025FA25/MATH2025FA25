# %% [markdown]
# # HW 07: Lego Prices
# - **Coder:** ____________________
# - **Developer:** ____________________
# - **Communicator:** ____________________

# %% [markdown]
# ## Introduction
# In this homework you will use multiple linear regression to fit and evaluate models using characteristics of LEGO sets to understand variability in the price.

# %% [markdown]
# ### Learning goals
# In this assignment, you will...
# - Use exploratory data analysis to inform feature engineering steps
# - Evaluate and compare models
# - Assess model conditions
# - Use inference to draw conclusions
# - Practice using AI to help with coding tasks

# %% [markdown]
# ### Packages
# The following packages will be used in this assignment:

# %%
library(tidyverse)
library(broom)
library(ggformula)
library(rms)
library(patchwork)
# add other packages as needed

# %% [markdown]
# ## Data: LEGOs
# The data for this analysis includes information about LEGO sets from themes produced January 1, 2018 and September 11, 2020. The data were originally scraped from Brickset.com, an online LEGO set guide and were obtained for this assignment from Peterson and Ziegla (2021 -> (Citation: Peterson and Ziegla 2021)).
# You will work with data on about 400 randomly selected LEGO sets produced during this time period. The primary variables are interest in this analysis are
# - `Pieces`: Number of pieces in the set from brickset.com.
# - `Minifigures`: Number of minifigures (LEGO people) in the set scraped from brickset.com. LEGO sets with no minifigures have been coded as NA. NA's also represent missing data. This is due to how brickset.com reports their data.
# - `Amazon_Price`: Amazon price of the set scraped from brickset.com (in U.S. dollars)
# - `Size`: General size of the interlocking bricks (Large = LEGO Duplo sets - which include large brick pieces safe for children ages 1 to 5, Small = LEGO sets which- include the traditional smaller brick pieces created for age groups 5 and - older, e.g., City, Friends)
# - `Theme`: Theme of the LEGO set
# - `Year` : Year the LEGO set was produced
# - `Pages`: Number of pages in the instruction booklet

# %% [markdown]
# # Exercises

# %% [markdown]
# ## Exercise 1
# The data are contained in `lego-sample.csv`. Use the code below to read in the data, replace the NAs in Minifigure with 0, and remove any observations that have missing values for the relevant variables.
# Let's think about the analysis decisions we just made. We decided to drop all observations that have missing values for any of the relevant variables we identified. What are the advantages and disadvantages of doing this? Feel free to Google 'structurally missing data'. We also replaced ALL of the NAs in Minifigures with 0's. What are the advantages and disadvantages of doing this? Make sure you read the description of Minifigures in the introduction before answering.

# %%
legos <- read_csv('lego-sample.csv') |>
  select(Size, Pieces, Theme, Amazon_Price, Year, Pages, Minifigures) |>
  mutate(Minifigures = replace_na(Minifigures, 0)) |>
  drop_na()

# %% [markdown]
# Insert interpretation here.

# %% [markdown]
# ## Exercise 2
# Visualize the distributions of the predictor variables Pieces, Size, Year, and Pages. Neatly arrange the plots using the patchwork package. Create univariate visualizations not bivariate visualizations.

# %%
# Insert code here

# %% [markdown]
# Insert interpretation here.

# %% [markdown]
# ## Exercise 3
# The distribution of Theme is shown below. The bars are ordered by the frequency they occur in the data set.
# Based solely on information that is visible in this plot, what is one reason we should avoid putting the variable Theme in a model as is?

# %%
legos |>
  count(Theme) |>
  mutate(Theme = fct_reorder(Theme, n)) |> 
  gf_col(Theme ~ n) |> 
    gf_labs(title = 'Lego Set Theme', 
         y = 'Theme', 
         x = 'Number of LEGO sets')

# %% [markdown]
# Insert interpretation here.

# %% [markdown]
# ## Exercise 4
# Let's practice using AI to help with R coding! Our goal here is going to be to create a new variable called `Theme_coarse` that collapses any levels of `Theme` with fewer than 20 observations into a single category called `Other`. We could just ask an AI to do this for us, but there are lot of ways to accomplish the same task in R so we want to be a bit more specific with our prompt. Fill in the blanks of the prompts below and paste them into your favorite AI chat window **MAKING SURE TO GENERATE A NEW CHAT BETWEEN PROMPT 1 AND PROMPT2**. Paste the code from the first prompt into the first code cell below and the code from the second prompt into the second code cell below.
#
# **Prompt 1:**
# Create a new variable called Theme_coarse that collapses any levels of Theme with fewer than 20 observations into a single category called Other.
#
# **Prompt 2:**
# Write R code that takes a data frame called [insert name here] and creates a new variable called [insert new name here] that collapses any levels of the variable [insert old name here] with fewer than 20 observations into a single category called Other. Use the function fct_lump_min within a mutate statement to accomplish this.
#
# Describe the differences (if any) between the code generated by the two prompts. Do both pieces of code work as intended? Which one do you prefer and why? Are there any aspects of the code that are different than how we usually write code? Before heanding on to the next exercise, comment out the first piece of code by highlighting it and pressing `Ctrl` + `/`.

# %%
# Insert result of prompt 1

# %%
# Insert result of prompt 2

# %% [markdown]
# Insert interpretation here.

# %% [markdown]
# ## Exercise 5
# Fit a model that uses the variables `Size`, `Theme_coarse`, and `Pages` to predict `Amazon_Price`. Call this `model1`.

# %%
# Insert code here

# %% [markdown]
# Insert interpretation here.

# %% [markdown]
# ## Exercise 6
# Create a new variable called `since2018` that calculates the number of years since 2018 based on the variable `Year`. You may learn what you used in Exercise 4 to write a prompt to generate this code. If you do so, please include the prompt you used below. While you are allowed to use AI to help you write code, it MUST be code that reflects the style and practices we have used in this course. For example, the following code would wirk but NOT be acceptable:
#
# ```R
# lego$since2018 <- lego$Year - 2018
# ```
#
# While this may seem silly now, there will be times in the future when you want to use AI to help you write code but you will need to make sure the code fits with the style and practices you are using in your project.

# %%
# Insert code here

# %% [markdown]
# Insert prompt here.

# %% [markdown]
# # Practice Using AI: RULES
#
# For the remainder of this homework, you are encouraged to practice using AI to write your code for you. Your goal should be to get your AI companion to write your desired code. Rules:
#
# - Your interpretation must be your own work and not generated by AI. Only your code may be generated by AI.
# - You must provide the prompt you used to generate the code.
# - Make sure the code reflects the style and practices we have used in this course. Code that does not reflect the style and practices we have used in this course will not receive credit.
# - If you cannot use AI to generate the code you need, you are more than welcome write the code yourself.
#
# ## Tips
#
# - Be as specific as possible in your prompt. The more specific you are, the more likely you are to get the code you want.
# - Describe the data you are working with in your prompt. For example, if you are working with a data frame called `lego`, make sure to include that in your prompt and describe the variables you are working with.
# - If the code generated by AI does not work as intended, try to identify what is wrong with the code and include that in your next prompt.
# - Describe the functions you want to use in your prompt. For example, if you want to use the `mutate` function make sure to include that in your prompt.
# - AI will typically include library calls in the code it generates. You do not need to include these in your final code unless you have not already loaded the package in your notebook.
# - You may need to modify the code that AI generates to make it work as intended. This is okay as long as the code reflects the style and practices we have used in this course.
# - Some conventions we use in this class that will help you write your prompts:
#   - Use the pipe operator `|>` to chain functions together
#   - Use `ggformula` for generating visualizations

# %% [markdown]
# ## Exercise 7
# Now let's consider a new model that includes all the variables used in the model from Exercise 5 along with `since2018`, `Pieces`, and `Minifigures`. Call this `model2`.

# %%
# Insert code here

# %% [markdown]
# Insert prompt here if you used one.

# %% [markdown]
# ## Exercise 8
# Compute the $R^2$, $R^2_{adj}$, AIC, and BIC for `model1` and `model2`. Based on your results, what model do you believe is the 'best' model? Justify your answer citing specific evidence from the values you just generated. Note, they may not all be useful.

# %%
# Insert code here

# %% [markdown]
# Insert prompt here. Be careful, if you are not specific, AI will almost certainly generate code that does not reflect the style and practices we have used in this course.

# %% [markdown]
# Instert interpretation here.

# %% [markdown]
# ## Exercise 9
# For whichever model you chose above, determine whether the conditions for inference are met. To propertly answer this question, you will need to create the appropriate diagnostic plots and interpret them.

# %%
# Insert code here

# %% [markdown]
# Insert prompt here. Be careful, if you are not specific, AI will almost certainly generate code that does not reflect the style and practices we have used in this course.

# %% [markdown]
# Insert interpretation here.

# %% [markdown]
# ## Exercise 10
# For the same model, conduct an F-test and interpret your results in the context of the problem. Make sure to:
# 1. Identify the null and alternative hypotheses.
# 2. Compute the F-statistic.
# 3. Compute the p-value.
# 4. Interpret the result of your test at a significance level of $\alpha = 0.05$

# %%
# Insert code here

# %% [markdown]
# Insert AI prompt here if you used one.

# %% [markdown]
# Insert interpretation here.

# %% [markdown]
# # Grading (18 points)
# | Component             | Points |
# |-----------------------|--------|
# | Ex 1                  | 2      |
# | Ex 2                  | 1      |
# | Ex 3                  | 1      |
# | Ex 4                  | 1      |
# | Ex 5                  | 1      |
# | Ex 6                  | 1      |
# | Ex 7                  | 1      |
# | Ex 8                  | 4      |
# | Ex 9                  | 2      |
# | Ex 10                 | 2      |
# | Grammar & Writing     | 1      |
# | Workflow & formatting | 1      |
#
# [^1]: The 'Grammar & Writing' grade is decided based on your grammar and writing. This is typically decided by choosing one of the questions and assessing the writing.
# [^2]: The 'Workflow & formatting' grade is to assess the reproducible workflow and document format. This includes having a neatly organized document with readable code and your name and the date in the YAML.
