# %% [markdown]
# # AE 14: Inference for Multiple Linear Regression
# ### Tadpoles
#
# - **Coder:** ____________________
# - **Developer:** ____________________
# - **Communicator:** ____________________

# %% [markdown]
# ## Packages + data
#
# The data for this AE is originall from [this paper](https://www.researchgate.net/profile/Kyle-Lynch-2/publication/235749481_Optimal_digestion_theory_does_not_predict_the_effect_of_pathogens_on_intestinal_plasticity/links/0deec51b55ffeec048000000/Optimal-digestion-theory-does-not-predict-the-effect-of-pathogens-on-intestinal-plasticity.pdf) and can be found in the `Tadpoles` dataset in the `Stat2Data` package. The abstract of this paper is as follows:
#
# > One prediction of optimal digestion theory is that organisms will increase the relative length of their digestive tracts when food resources become limited. We used theory of optimal digestion to test whether tadpoles can adjust the relative length of their intestines when challenged with the fungal pathogen *Batrachochytrium dendrobatidis (Bd)*. The degree of tadpole mouthpart damage, a symptom of Bd infections that reduces food consumption, was associated positively with the length of tadpole intestines relative to their
# body size, consistent with optimal digestion theory. After controlling for mouthpart damage, tadpoles exposed to Bd had shorter intestines relative to their body size, opposite to the predictions of optimal digestion theory. One explanation of why tadpoles with higher `Bd` loads have shorter relative intestinal lengths is that they divert energy from maintaining intestinal and overall growth towards anti-parasite defences.
#
# **Variables**
#
# - `Treatment`: Exposed to fungus (Bd=yes or Control=no)
# - `Body`: Length of body (in mm)
# - `GutLength`: Length of intestine (in mm)
# - `MouthpartDamage`: Measure of damage to the mouth (e.g. missing teeth)

# %%
library(tidyverse)
library(ggformula)
library(broom)
library(Stat2Data)
library(mosaic)
library(mosaicData)

data("Tadpoles")
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.2
# ✔ ggplot2   3.5.2     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.1.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package to force all conflicts to become errors
# Loading required package: scales
#
# Attaching package: ‘scales’
#
# The following object is masked from ‘package:purrr’:
#
#     discard
#
# The following object is masked from ‘package:readr’:
#
#     col_factor
#
# Loading required package: ggridges
#
# New to ggformula?  Try the tutorials:
# 	learnr::run_tutorial("introduction", package = "ggformula")
# 	learnr::run_tutorial("refining", package = "ggformula")
# Registered S3 method overwritten by 'mosaic':
# ...

# %% [markdown]
# ## Analysis goals
#
# The goals of this activity are to:
#
# - Perform inference for multiple linear regression
# - Conduct/interpret hypothesis tests
# - Conduct a power analysis

# %% [markdown]
# ## Exercise 0
#
# Let's begin by thinking about the problem. Answer the following questions based on the variables you have and the abstract copied above:
#
# - What is the primary resarch question here?
# - What is the main response variable of interest?
# - What is the main explanatory variable of interest?
# - What are potential confounding variables that should be controlled for?

# %% [markdown]
# ## Exercise 1
#
# Create a plot of the primary explanatory variable vs. the response variable. Describe any patterns you see in the data.

# %%
# Insert Code Here

# %% [markdown]
# Insert interpretation here

# %% [markdown]
# ## Exercise 2
#
# Fit a *simple* linear model with the response variable and the primary explanatory variable only. Interpret the coefficients in the model, and describe whether there is a significant association between the two variables.

# %%
# Insert code here

# %% [markdown]
# Insert interpretation here

# %% [markdown]
# ## Exercise 3
#
# Fit a *multiple* linear regression model in which you control for the confounding variables you identified in the first exercise. Interpret the coefficients in the model.

# %%
# Insert code here

# %% [markdown]
# Insert interpretation here

# %% [markdown]
# ## Exercise 4
#
# Consider the model *with* an interaction term. Interpret the the p-value associated with the interaction term.

# %% [markdown]
# Insert interpretation here

# %% [markdown]
# ## Exercise 5
#
# Generate 95% confidence intervals for the model *without* an interaction term. Hint: use the `tidy` function with the argument `conf.int = TRUE`. Interpret the confidence interval for the same explanatory variable as Exercise 3 and explain why the combination of p-value and confidence interval makes sense.

# %%
# Insert code here

# %% [markdown]
# Insert interpretation here

# %% [markdown]
# ## Exercise 6
#
# What does it mean for two things to be **independent** in statistics (feel free to use Google)? Do we think our p-values/confidence intervals are **independent** across variables?

# %% [markdown]
# Insert interpretation here

# %% [markdown]
# <div style="background-color:#f8d7da; padding:1em; border-radius:6px; border:1px solid #f5c2c7;">
# <strong>Important</strong>
# <ul>
# <li>If the intercept term was significant, use that model for the rest of this activity, otherwise use the model without the interaction term.</li>
# </ul>
# </div>

# %% [markdown]
# ## Exercise 7
#
# Generate a scatter plot of the residuals vs. the fitted values for this model.

# %%
# Insert code here

# %% [markdown]
# Insert interpretation here

# %% [markdown]
# ## Exercise 8
#
# Plot the residuals vs. each of your predictors (two plots total).

# %%
# Insert code here

# %%
# Insert code here

# %% [markdown]
# Insert interpretation here

# %% [markdown]
# ## Exercise 9
#
# Based on the three plots you've made, do you think the linearity condition is satisfied?

# %% [markdown]
# Insert interpretation here

# %% [markdown]
# ## Exercise 10
#
# We check the constant variance assumption in the same way we do with SLR. To what extent does the constant variance condition seem to be satisfied?

# %% [markdown]
# Insert interpretation here

# %% [markdown]
# ## Exercise 11
#
# Generate a histogram and QQ-plot of the residuals. To what extent do you believe the normality condition is satisfied?

# %%
# Insert code here

# %%
# Insert code here

# %% [markdown]
# Insert interpretation here

# %% [markdown]
# ## Exercise 12
#
# How do you think would you go about checking the independence condition?

# %% [markdown]
# Insert interpretation here

# %% [markdown]
# <div style="background-color:#f8d7da; padding:1em; border-radius:6px; border:1px solid #f5c2c7;">
# <strong>Important</strong>
# <ul>
# <li>Run all cells in this notebook to produce the HTML file with all of your work from today's class.</li>
# <li>Upload your notebook and HTML files to the Canvas assignment.</li>
# </ul>
# </div>

# %% [markdown]
# ### Required files
# - `rail-trail.csv` (must be present in `../data/` relative to notebook location)
