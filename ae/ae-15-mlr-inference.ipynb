# %% [markdown]
# # AE 15: Inference for Multiple Linear Regression
# ### Tadpoles
#
# - **Coder:**
# - **Developer:**
# - **Communicator:**

# %% [markdown]
# ## Packages + data
#
# This data is called `Tadpoles` and is from [this study](https://pmc.ncbi.nlm.nih.gov/articles/PMC3639782/pdf/rsbl20130038.pdf) via the `Stat2Data` package. The abstract of this study reads:
#
# >  One prediction of optimal digestion theory is that organisms will increase the relative length of their digestive tracts when food resources become limited. We used theory of optimal digestion to test whether tadpoles can adjust the relative length of their intestines when challenged with the fungal pathogen `Batrachochytrium dendrobatidis (Bd)`. The degree of tadpole mouthpart damage, a symptom of `Bd` infections that reduces food consumption, was associated positively with the length of tadpole intestines relative to their body size, consistent with optimal digestion theory. After controlling for mouthpart damage, tadpoles exposed to Bd had shorter intestines relative to their body size, opposite to the predictions of optimal digestion theory. One explanation of why tadpoles with higher `Bd` loads have shorter relative intestinal lengths is that they divert energy from maintaining intestinal and overall growth towards anti-parasite defences.
#
# The variables in the `Tadpoles` data frame are:
#
# - `Treatment` Exposed to fungus (Bd=yes or Control=no)
# -  `Body` Length of body (in mm)
# -  `GutLength` Length of intestine (in mm)
# -  `MouthpartDamage` Measure of damage to the mouth (e.g. missing teeth)

# %%
library(tidyverse)
library(ggformula)
library(broom)
library(mosaic)
library(Stat2Data)

data("Tadpoles")

# %% [markdown]
# ## Analysis goal
#
# The goals of this activity are to:
#
# - Perform inference for multiple linear regression
# - Conduct/interpret hypothesis tests
# - Construct/interpret confidence intervals
# - Conduct a power analysis

# %% [markdown]
# ## Exercise 0
# Read the abstract and review the variable definitions above. Then answer these questions:
#
# 1. What is the response variable in this study?
# 2. What is the primary explanatory variable in this study?
# 3. What the primary research question the researchers are trying to answer? Write this in your own words referencing specific variables.
# 4. What are potential confounding variables in this study?

# %% [markdown]
# Insert answers here.

# %% [markdown]
# ## Exercise 1
# Fit a simple linear regression model using only the primary explanatory variable identified in Exercise 0 to predict the response variable. Interpret the coefficient and p-value. Be prepared to discuss the implications for the research question.

# %%
# Insert code here

# %% [markdown]
# Insert interpretation here

# %% [markdown]
# ## Exercise 2
# Based on our dicussion in class. Fit a model that controls for our confounding variables. Display the model using `tidy`.

# %%
# Insert code here

# %% [markdown]
# ## Exercise 3
# Consider the model you created. Perform a hypothesis test on the appropriate explanatory variable (fill in the blanks where appropriate):
#
# 1.  **Set hypothesis:** $H_0: \beta_{fill in} [fill in]$ vs. $\beta_{fill in} [fill in]$. Restate these hypothesis in words: [fill in]
# 2.  **Calculate test statistics and p-value:** The test statistic is [fill in]. The p-value is [fill in].
# 3.  **State the conclusion:** [fill in]

# %% [markdown]
# Insert interpretation here

# %% [markdown]
# ## Exercise 4
# What sample size would you need to achieve a power of 0.7 to detect an effect of the primary explanatory variable on the response variable, assuming the effect size observed in the model you created? Show your code and interpretation.

# %%
# Insert code here

# %% [markdown]
# Insert interpretation here

# %% [markdown]
# ## Exercise 5
# Generate 95% confidence intervals for you model. Hint: use the `tidy` function with the argument `conf.int = TRUE`. Interpret the confidence interval for the same explanatory variable as Exercise 3 and explain why the combination of p-value and confidence interval makes sense.

# %%
# Insert code here

# %% [markdown]
# Insert interpretation here
