# %% [markdown]
# # AE 13: Multiple Linear Regression
#
# - **Coder:**
# - **Developer:**
# - **Communicator:**

# %% [markdown]
# ## Packages + data
#
# The data for this AE is from the `Credit` data set in the <b>ISLR2</b> R package. It is a simulated data set of 400 credit card customers. We will focus on predicing credit limit using multiple linear regression.

# %%
library(tidyverse)
library(ggformula)
library(broom)
library(mosaic)
library(ISLR2)
library(GGally)
library(yardstick)

# %% [markdown]
# ## Analysis goal
#
# The goals of this analysis is to fit a multiple linear regression model that that predicts a person's credit limit.

# %% [markdown]
# ## Exercise 0
#
# Look at the documentation for the data [here](https://rdrr.io/cran/ISLR2/man/Credit.html) and Google to figure out what the variables represents. What is a credit rating and what is a credit limit as it applies to a credit card? The primary credit rating in the US is called a FICO score. Use `favstats` on `Rating`. Do you think that `Rating` corresponds to the borrower's FICO score?
#
# Without writing any more code (i.e. just using what you know about the world):
#
# -   Do you think `Rating` will be a good predictor of `Limit`?
# -   In addition to `Rating`, choose a second quantitative variable (other than `Balance`), that you think will be predictive of `Limit`.

# %%
# Insert code here

# %% [markdown]
# Insert interpretation here.

# %% [markdown]
# ## Exercise 1
#
# Use the function `ggpairs` from the `GGally` package (already loaded) to create a matrix of plots and correlations for your four variables of interest. Note that you will have to use `select` to select the three columns you are interested in. Which variable do you think will be the best predictor of `Limit`?

# %%
Credit |> 
  select(Limit, Rating) |> # add your extra variables here.
  ggpairs()

# %% [markdown]
# Insert interpretation here.

# %% [markdown]
# ## Exercise 2
#
# Fit a linear model with just `Rating` as the predictor and get the p-value associated with it's coefficient. Is it statistically significant?

# %%
# Insert code here

# %% [markdown]
# Insert interpretation here.

# %% [markdown]
# ## Exercise 3
#
# Fit a linear model with just your second quantitative predictor and get the p-value associated with it's coefficient. Is it statistically significant?

# %%
# Insert code here

# %% [markdown]
# Insert interpretation here.

# %% [markdown]
# ## Exercise 4
#
# Fit a model with both `Rating` and your second quantitative variable as predictors. Find a spot on the white board to write down an equation representing the fitted model. How do the coefficients and p-values of for your predictors compare to those in the two models above? Discuss what you see and the possible reasons you see them.

# %%
# Insert code here

# %% [markdown]
# Insert interpretation here.

# %% [markdown]
# ## Exercise 5
#
# Interpret all coefficients in the model.

# %% [markdown]
# Insert interpretation here.

# %% [markdown]
# ## Exercise 6
#
# Use `head` to look at the first six observation in the data set. Use addition, subtraction, multiplication, and division to figure out what credit limit your model would predict for a person with the same characteristics of the first person.

# %%
# Insert code here

# %% [markdown]
# Insert interpretation here.

# %% [markdown]
# ## Exercise 7
#
# Now use the `predict` function to verify the value you computed in the previous exercise and compute a 90% prediction interval. How would you interpret this interval in context?

# %%
# Insert code here

# %% [markdown]
# Insert interpretation here.
