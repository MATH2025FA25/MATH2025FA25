# %% [markdown]
# # AE 14: Categorical Variables
#
# - **Coder:**
# - **Developer:**
# - **Communicator:**

# %% [markdown]
# ## Packages + data
#
# The data for this AE is from the `Credit` data set in the <b>ISLR2</b> R package. It is a simulated data set of 400 credit card customers. We will focus on predicing credit limit using multiple linear regression.

# %%
library(tidyverse)
library(ggformula)
library(broom)
library(mosaic)
library(ISLR2)
library(GGally)
library(yardstick)

# %% [markdown]
# ## Analysis goal
#
# The goals of this analysis is to fit a multiple linear regression model that that predicts a person's credit limit.

# %% [markdown]
# ## Exercise 0
#
# Look at the documentation for the data [here](https://rdrr.io/cran/ISLR2/man/Credit.html) and Google to figure out what the variables represents.
#
# Without writing any more code (i.e. just using what you know about the world), choose a two quantitative variables (other than `Balance`) and one categorical variables, that you think will be predictive of `Limit`.

# %%
# Insert code here

# %% [markdown]
# Insert interpretation here.

# %% [markdown]
# ## Exercise 1
#
# Use the function `ggpairs` from the `GGally` package (already loaded) to create a matrix of plots and correlations for your four variables of interest. Note that you will have to use `select` to select the four columns you are interested in. Which variable do you think will be the best predictor of `Limit`?

# %%
Credit |> 
  select(Limit) |> # add your extra variables here.
  ggpairs()

# %% [markdown]
# Insert interpretation here.

# %% [markdown]
# ## Exercise 2
#
# Fit a linear model predicting `Limit` from ONLY your categorical variable. What is the reference level?

# %%
# Insert code here

# %% [markdown]
# Insert interpretation here.

# %% [markdown]
# ## Exercise 3
#
# WITHOUT WRITING ANY CODE except for addition, subtraction, multiplication, and addition, what would the model predict the average `Limit` to be for each of the level of your categorical variable?

# %%
# Insert code here

# %% [markdown]
# Insert interpretation here.

# %% [markdown]
# ## Exercise 4
#
# Compute the average `Limit` for each level in your categorical variable. Hint: you can use "formulas" (i.e. `repsonse ~ explanatory`) in the `mean` function from the `mosaic` package. How do these answers compare to your answers from Exercise 3?

# %%
# Insert code here

# %% [markdown]
# Insert interpretation here.

# %% [markdown]
# ## Exercise 5
#
# Choose one of your quantiative variables (not `Rating`). Fit a linear model using your quantitative and your categorical variable as predictors. Use the function `plotModel` to make a nifty plot for your model. Your syntax should look like `plotModel(model_name)`.

# %% [markdown]
# Insert interpretation here.

# %% [markdown]
# ## Exercise 6
#
# Your model contains one line for every level of your categorical variable. On the board, write out the equations for two of them.

# %% [markdown]
# ## Exercise 7
#
# How do you think the plot above will change if you add in an interaction term between your variables? AFTER thinking about it, add in the interaction term and plot the model using `plotModel`.

# %%
# Insert code here

# %% [markdown]
# Insert interpretation here.

# %% [markdown]
# ## Exercise 8
#
# Your model contains one line for every level of your categorical variable. On the board, write out the equations for two of them.

# %% [markdown]
# ## Exercise 9
#
# Fit a model with your two quantitative predictors and an interaction term. Write your model on the board.

# %%
# Insert code here

# %% [markdown]
# ## Exercise 10 (Optional)
#
# Look back at all of the models that you've fit. If you compare the p-values for the same variable across multiple models, what do you notice?

# %% [markdown]
# Insert interpretation here.

# %% [markdown]
# ## Exercise 11 (Optional)
#
# Note that this data set only considers borrowers who have actually been granted loans. How does this impact the generalizability of our analysis?

# %% [markdown]
# Insert interpretation here.
